# %%
#Task-1
import pandas as pd
import numpy as np
data = np.random.randn(4, 4)
df = pd.DataFrame(data, columns=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4'])
print(df)
# Out:
#    Feature 1  Feature 2  Feature 3  Feature 4
# 0  -0.675935   0.060871  -0.526097   1.544996
# 1   1.863868  -0.039961   0.875630  -0.457941
# 2  -0.226287  -0.127422   1.549660  -0.336658
# 3   0.907080   2.621522  -0.015047   0.741974

# %%
#Task-2
import pandas as pd
import numpy as np
data = np.random.randn(4, 4)
df = pd.DataFrame(data, columns=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4'])
df = df.rename(columns={'Feature 1': 'Random value 1','Feature 2': 'Random value 2', 
                        'Feature 3': 'Random value 3','Feature 4': 'Random value 4'})
print(df)
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0       -0.090097       -1.674813       -0.592077       -0.429951
# 1       -0.774284        0.213732        2.115307        0.404319
# 2        0.219362       -0.927937       -0.281863        0.481657
# 3        1.732517       -0.224661       -0.044913        0.055041

# %%
#Task-3
statistics = df.describe()
print(statistics)
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.271875       -0.653420        0.299113        0.127766
# std          1.058569        0.827524        1.231350        0.415555
# min         -0.774284       -1.674813       -0.592077       -0.429951
# 25%         -0.261144       -1.114656       -0.359417       -0.066207
# 50%          0.064632       -0.576299       -0.163388        0.229680
# 75%          0.597651       -0.115063        0.495142        0.423653
# max          1.732517        0.213732        2.115307        0.481657

# %%
#Task-4
null_value = df.isnull().sum()
print("Null Value:\n", null_value)
data_type = df.dtypes
print("\nData Type:\n", data_type)
# Out:
# Null Value:
#  Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64
#
# Data Type:
#  Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %%
#Task-5
import pandas as pd
import numpy as np
data = np.random.randn(4, 4)
df = pd.DataFrame(data, columns=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4'])
df = df.rename(columns={'Feature 2': 'Random value 2', 'Feature 3': 'Random value 3'})
print("Random value 2 using location method:\n", df.loc[:, 'Random value 2'])
print("\nRandom value 3 using index location method:\n", df.iloc[:, 2])
# Out:
# Random value 2 using location method:
#  0    0.595365
# 1   -1.108508
# 2    0.319316
# 3   -0.117085
# Name: Random value 2, dtype: float64
#
# Random value 3 using index location method:
#  0    0.363024
# 1   -0.359931
# 2   -1.785957
# 3    0.137304
# Name: Random value 3, dtype: float64
